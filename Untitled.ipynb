# %% [markdown]
# Problem Statement 1:
#
# In each of the following situations, state whether it is a correctly stated hypothesis testing problem and why?
#
# 1.	 0:   = 25,  1:   ≠ 25
# 2.	 0:   > 10,  1:   = 10
# 3.	 0:    = 50,  1:    ≠ 50
# 4.	 0:   = 0.1,  1:   = 0.5
# 5.	 0:   = 30,  1:   > 30

# %%
from IPython.display import Image
print("SOLUTION")
Image(filename='as-2,1-1.jpeg')
# Out:
# SOLUTION

# %%
Image(filename='as-2,1-2.jpeg')

# %% [markdown]
#
# Problem Statement 2:
#
# The college bookstore tells prospective students that the average cost of its textbooks is Rs. 52 with a standard deviation of Rs. 4.50. A group of smart statistics students thinks that the average cost is higher. To test the bookstore’s claim against their alternative, the students will select a random sample of size 100. Assume that the mean from their random sample is Rs. 52.80. Perform a hypothesis test at the 5% level of significance and state your decision.

# %%
print("SOLUTION")
Image(filename='as-2,2.jpeg')
# Out:
# SOLUTION

# %% [markdown]
#
# Problem Statement 3:
#
# A certain chemical pollutant in the Genesee River has been constant for several years with mean μ = 34 ppm (parts per million) and standard deviation σ = 8 ppm. A group of factory representatives whose companies discharge liquids into the river is now claiming that they have lowered the average with improved filtration devices. A
# group of environmentalists will test to see if this is true at the 1% level of significance. Assume \ that their sample of size 50 gives a mean of 32.5 ppm. Perform a hypothesis test at the 1% level of significance and state your decision.

# %%
print("SOLUTION")
Image(filename='as-2,3.jpeg')
# Out:
# SOLUTION

# %% [markdown]
#
# Problem Statement 4:
#
# Based on population figures and other general information on the U.S. population, suppose it has been estimated that, on average, a family of four in the U.S. spends about $1135 annually on dental expenditures. Suppose further that a regional dental association wants to test to determine if this figure is accurate for their area of country. To test this, 22 families of 4 are randomly selected from the population in that area of the country and a log is kept of the family’s dental expenditure for one year. The resulting data are given below. Assuming, that dental expenditure is normally distributed in the population, use the data and an alpha of 0.5 to test the dental association’s hypothesis.
#
# 1008, 812, 1117, 1323, 1308, 1415, 831, 1021, 1287, 851, 930, 730, 699, 872, 913, 944, 954, 987, 1695, 995, 1003, 994

# %%
print("SOLUTION")
Image(filename='as-2,4.jpeg')
# Out:
# SOLUTION

# %% [markdown]
#
# Problem Statement 5:
#
# In a report prepared by the Economic Research Department of a major bank the Department manager maintains that the average annual family income on Metropolis is $ 48,432. What do you conclude about the validity of the report if a random sample of 400 families shows and average income of $48,574 with a standard deviation of 2000?

# %%
print("SOLUTION")
Image(filename='as-2,5.jpeg')
# Out:
# SOLUTION

# %%
Image(filename='6.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,6.jpg')
# Out:
# SOLUTION

# %%
Image(filename='7.jpg')

# %%
Image(filename='8.jpg')

# %%
Image(filename='9.jpg')

# %%
Image(filename='10.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,10-1.jpg')
# Out:
# SOLUTION

# %%
Image(filename='as-2,10-2.jpg')

# %%
Image(filename='11.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,11-1.jpg')
# Out:
# SOLUTION

# %%
Image(filename='as-2,11-2.jpg')

# %%
Image(filename='12.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,12-1.jpg')
# Out:
# SOLUTION

# %%
Image(filename='as-2,12-2.jpg')

# %%
Image(filename='13.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,13.jpg')
# Out:
# SOLUTION

# %%
Image(filename='14.jpg')

# %%
Image(filename='15.jpg')

# %%
Image(filename='16.jpg')

# %%
Image(filename='17.jpg')

# %% [markdown]
# SOLUTION:
# Die is unbiased since:
#
#  --the outcome is not equally likely
#
# --that is the probability of each number 1/6, when rolled 132 times, outcome must be 22

# %%
Image(filename='18.jpg')

# %% [markdown]
# gender and voting are independent since:
#
#   --male has lower number voted and at the same time has the lower number not voted
#
# --female has the higher number of voted and at the same time higher number not voted
#
# These happened probably because female population is larger than male

# %%
Image(filename='19.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,19.jpg')
# Out:
# SOLUTION

# %% [markdown]
# Since the test statistic falls within the rejection region, Ho is rejected. This suggests that there is sufficient evidence to state that age is independent of photo preference. Despite such, one of the cell values is less than 5 which breaks one of chi-square tests  assumption.

# %%
Image(filename='20.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,20.jpg')
# Out:
# SOLUTION

# %% [markdown]
# Since the test statistic falls within the rejection region, Ho is rejected. This suggests that there is sufficient evidence to state that the candidates are not equally popular.

# %% [markdown]
#  problem 21:
# A study of conformity using the Asch paradigm involved two conditions: one where one confederate 	ed the true judgement and another where no confederate gave the correct response.
#
# Is there a significant difference between the "support" and "no support" conditions in the frequency with which individuals are likely to conform? [Chi-Square = 19.87, with 1 df:    < 0.05].

# %%
Image(filename='21.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,21.jpg')
# Out:
# SOLUTION

# %% [markdown]
# The p-value=.00008 which is less than 0.05 level of significance, hence we reject the null hypothesis and conclude that there a significant difference between the "support" and "no support" conditions in the frequency with which individuals are likely to conform.

# %% [markdown]
# Problem Statement 22:
#
# We want to test whether short people differ with respect to their leadership qualities
# (Genghis Khan, Adolf Hitler and Napoleon were all stature-deprived, and how many midget MP's are there?) The following table shows the frequencies with which 43 short people and 52 tall people were categorized as "leaders", "followers" or as "unclassifiable". Is there a relationship between height and leadership qualities?
# [Chi-Square = 10.71, with 2 df:    < 0.01].

# %%
Image(filename='22.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,22.jpg')
# Out:
# SOLUTION

# %% [markdown]
# The P-Value is .004724 which is less than 0.01 level of significance, hence we reject the null hypothesis and conclude that there a relationship between height and leadership qualities.

# %% [markdown]
# Problem Statement 23:
#
# Each respondent in the Current Population Survey of March 1993 was classified as employed, unemployed, or outside the labor force. The results for men in California age 3544 can be cross-tabulated by marital status, as follows:
# Men of different marital status seem to have different distributions of labor force status. Or is this just chance variation? (you may assume the table results from a simple random sample.)

# %%
Image(filename='23.jpg')

# %%
Image(filename='as-2,23-1.jpg')

# %%
print("SOLUTION")
Image(filename='as-2,23-2.jpg')
# Out:
# SOLUTION

# %% [markdown]
# p=0.00002
# Since the test statistic falls within the rejection region, Ho is rejected. This suggests that there is sufficient evidence to state that men of different marital status have different distributions of labor force status.
